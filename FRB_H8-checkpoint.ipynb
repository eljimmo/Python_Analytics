# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv(r"FRB_H8.csv")
# Out:
#       Series Description  \
# 0                  Unit:
# 1            Multiplier:
# 2              Currency:
# 3    Unique Identifier:
# 4            Time Period
# ..                   ...
# 301               2021Q2
# 302               2021Q3
# 303               2021Q4
# 304               2022Q1
# 305               2022Q2
#
#     Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                                    H8/H8/B1001NCBCQG
# 4                                          B1001NCBCQG
# ..                                                 ...
# 301                                                7.6
# 302                                                6.9
# 303                                               10.9
# 304                                                9.8
# ...

# %%
df = pd.read_csv(r"FRB_H8.csv")

# %%
df.shape
# Out:
# (306, 28)

# %%
df.head()
# Out:
#     Series Description  \
# 0                Unit:
# 1          Multiplier:
# 2            Currency:
# 3  Unique Identifier:
# 4          Time Period
#
#   Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# 0                                  Percent:_Per_Year
# 1                                                  1
# 2                                                NaN
# 3                                  H8/H8/B1001NCBCQG
# 4                                        B1001NCBCQG
#
#   Securities in bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# 0                                  Percent:_Per_Year
# 1                                                  1
# 2                                                NaN
# 3                                  H8/H8/B1002NCBCQG
# 4                                        B1002NCBCQG
#
# ...

# %%
df.tail(2)
# Out:
#     Series Description  \
# 304             2022Q1
# 305             2022Q2
#
#     Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# 304                                                9.8
# 305                                                8.0
#
#     Securities in bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# 304                                               10.6
# 305                                                0.4
#
#     Treasury and agency securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# 304                                               10.9
# 305                                               -0.6
#
#     Other securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# 304                                                9.3
# 305                                                4.3
#
# ...

# %%
df.columns
# Out:
# Index(['Series Description',
#        'Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)',
#        'Securities in bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)',
#        'Treasury and agency securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)',
#        'Other securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)',
#        'Loans and leases in bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)',
#        'Commercial and industrial loans, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)',
#        'Real estate loans, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)',
#        'Real estate loans: Residential real estate loans, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)',
# ...

# %%
df.dtypes
# Out:
# Series Description                                                                                                                                                object
# Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)                                                                       object
# Securities in bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)                                                         object
# Treasury and agency securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)                                                    object
# Other securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)                                                                  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 28 columns):
#  #   Column                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                          --------------  -----
#  0   Series Description                                                                                                                                              306 non-null    object
#  1   Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)                                                                     305 non-null    object
# ...

# %%
df.describe()
# Out:
#        Series Description  \
# count                 306
# unique                306
# top                 Unit:
# freq                    1
#
#        Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# count                                                 305
# unique                                                148
# top                                                   7.0
# freq                                                    7
#
#        Securities in bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# count                                                 305
# unique                                                206
# top                                                   6.1
# freq                                                    5
#
#        Treasury and agency securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# ...

# %%
df.describe(percentiles=[0.05, 0.95])
# Out:
#        Series Description  \
# count                 306
# unique                306
# top                 Unit:
# freq                    1
#
#        Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# count                                                 305
# unique                                                148
# top                                                   7.0
# freq                                                    7
#
#        Securities in bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# count                                                 305
# unique                                                206
# top                                                   6.1
# freq                                                    5
#
#        Treasury and agency securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# ...

# %%
df.describe(include='all')
# Out:
#        Series Description  \
# count                 306
# unique                306
# top                 Unit:
# freq                    1
#
#        Bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# count                                                 305
# unique                                                148
# top                                                   7.0
# freq                                                    7
#
#        Securities in bank credit, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# count                                                 305
# unique                                                206
# top                                                   6.1
# freq                                                    5
#
#        Treasury and agency securities, all commercial banks, seasonally adjusted, annual growth rate (break adjusted)  \
# ...
